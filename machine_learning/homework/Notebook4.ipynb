# %% [markdown]
# # Notebook \#4
#
# # Name: Nick Peters

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import libraries
import sklearn
import pandas
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import neighbors

# load data
housing_data = pandas.read_csv('/content/drive/MyDrive/CS167 Datasets/HousingData.csv')
housing_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# # Part 1: Clean and normalize the Data
# Clean and normalize the data (use the StandardScalar from sklearn). Replace any null values with the average of the columns. Verify that there are no null values by printing out the results of `housing_data.isna().any()`

# %%
# clean data here!!!
housing_data['CRIM'].fillna(housing_data['CRIM'].mean(), inplace=True)
housing_data['ZN'].fillna(housing_data['ZN'].mean(), inplace=True)
housing_data['INDUS'].fillna(housing_data['CRIM'].mean(), inplace=True)
housing_data['CHAS'].fillna(housing_data['CHAS'].mean(), inplace=True)
housing_data['AGE'].fillna(housing_data['AGE'].mean(), inplace=True)
housing_data['LSTAT'].fillna(housing_data['LSTAT'].mean(), inplace=True)
housing_data.isna().any() # look at all of these columns with null values!

#normalization will be in a later part after we split the data
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# LSTAT      False
# MEDV       False
# dtype: bool

# %% [markdown]
# ## Part 2: Using scikit learn (sklearn)
# You must run at least 6 variations of the algorithms and display their results using an appropriate regression metric (again, use the scikit-learn modules). I will be looking for the following to be included in your comparison:
#
# *   k-Nearest-Neighbor with a **small value of k**
# *   k-Nearest-Neighbor with a **large value of k**
# *   **weighted k-Nearest-Neighbor** with a **small value of k** (the same one you used for the unweighted version)
# *  **weighted k-Nearest-Neighbor** with a **large value of k** (the same one you used for the unweighted version)
# *   a **decision tree with default** parameter values
# *   a **decision tree**, setting some kind of parameter that results in a **smaller tree**
#
# You will need to use the documentation for sklearn for this Notebook. Here are some helpful links:
# * [K Neighbors Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)
# * [Decision Tree Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %%
# Split the data into the training data and testing data
target= 'MEDV'
predictors = housing_data.columns.drop(target) # use all of the columns except for MEDV
train_data, test_data, train_sln, test_sln = train_test_split(housing_data[predictors], housing_data[target], test_size = 0.2, random_state=41)
train_data.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 110  0.107930   0.0   8.56   0.0  0.520  6.195   54.4  2.7778    5  384
# 158  1.342840   0.0  19.58   0.0  0.605  6.066  100.0  1.7573    5  403
# 460  3.611874   0.0  18.10   0.0  0.713  6.701   90.0  2.5975   24  666
# 471  4.038410   0.0  18.10   0.0  0.532  6.229   90.7  3.0993   24  666
# 273  0.221880  20.0   6.96   1.0  0.464  7.691   51.8  4.3665    3  223
#
#      PTRATIO  LSTAT
# 110     20.9  13.00
# 158     14.7   6.43
# 460     20.2  16.42
# 471     20.2  12.87
# 273     18.6   6.58

# %%
from sklearn.preprocessing import StandardScaler

#normalization
scaler = StandardScaler()
scaler.fit(train_data)
train_data_normalized = scaler.transform(train_data)
test_data_normalized = scaler.transform(test_data)

# %%
# kNN with small k
small_knn = neighbors.KNeighborsRegressor(n_neighbors=5)
small_knn.fit(train_data_normalized, train_sln)
small_k_predict = small_knn.predict(test_data_normalized)
print('r2:', metrics.r2_score(test_sln, small_k_predict))
# Out:
# r2: 0.5365521824163144

# %%
# kNN with large k
large_knn = neighbors.KNeighborsRegressor(n_neighbors=25)
large_knn.fit(train_data_normalized, train_sln)
large_k_predict = large_knn.predict(test_data_normalized)
print('r2:', metrics.r2_score(test_sln, large_k_predict))
# Out:
# r2: 0.6906579051217955

# %%
# w-knn with small k
w_small_knn = neighbors.KNeighborsRegressor(n_neighbors=5, weights='distance')
w_small_knn.fit(train_data_normalized, train_sln)
w_small_k_predict = w_small_knn.predict(test_data_normalized)
print('r2:', metrics.r2_score(test_sln, w_small_k_predict))
# Out:
# r2: 0.6170966453189659

# %%
# w-knn with large k
w_large_knn = neighbors.KNeighborsRegressor(n_neighbors=25, weights='distance')
w_large_knn.fit(train_data_normalized, train_sln)
w_large_k_predict = large_knn.predict(test_data_normalized)
print('r2:', metrics.r2_score(test_sln, w_large_k_predict))
# Out:
# r2: 0.6906579051217955

# %%
# decision tree with default paramters
dt = tree.DecisionTreeRegressor(random_state=0)
dt.fit(train_data, train_sln)
dt_predict = dt.predict(test_data)
print('r2:', metrics.r2_score(test_sln, dt_predict))
# Out:
# r2: -0.06783551410598387

# %%
# decision tree with some kind of parameter that (hopefully) results in a smaller tree
small_dt = tree.DecisionTreeRegressor(random_state=0, max_depth=4)
small_dt.fit(train_data, train_sln)
small_dt_predict = dt.predict(test_data)
print('r2:', metrics.r2_score(test_sln, small_dt_predict))
# Out:
# r2: -0.06783551410598387

# %% [markdown]
# ## Part 3: Conclusions
# What algorithm performed better? kNN or Decision Trees? Why do you think this was the case?
#
# kNN consistently achieved a higher r^2 value than decision trees did. Because of this, it is easy to say that kNN performed better. Decision trees performed so poor on this dataset that both r^2 values were negative, meaning they were worse at guessing the target value of the test cases than the average was. This could indicate that, in the dataset, there is no one good value for gaining information in order to predict new values of the target. In comparison, the success of the kNN algorithm could indicate that multiple or all of the predictors are important for predicting new values of the target.
